# %% [markdown]
# # PyCity Schools Analysis
#
# * As a whole, schools with higher budgets, did not yield better test results. By contrast, schools with higher spending per student actually (\\$645 - 675) underperformed compared to schools with smaller budgets (\\$585 per student).
#
# * As a whole, smaller and medium sized schools dramatically out-performed large sized schools on passing math performances (89-91% passing vs 67%).
#
# * As a whole, charter schools out-performed the public district schools across all metrics. However, more analysis will be required to glean if the effect is due to school practices or the fact that charter schools tend to serve smaller student populations per school.
# ---

# %% [markdown]
# **Note:**
# Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
school_data_to_load = "data/schools_complete.csv"
student_data_to_load = "data/students_complete.csv"

# Read School and Student Data File and store into Pandas Data Frames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete.head()

# school_data_complete.count()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the overall passing rate (overall average score), i.e. (avg. math score + avg. reading score)/2
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
# Create a District Summary
school_data_complete.describe()
# Out:
#          Student ID  reading_score    math_score     School ID          size  \
# count  39170.000000    39170.00000  39170.000000  39170.000000  39170.000000
# mean   19584.500000       81.87784     78.985371      6.978172   3332.957110
# std    11307.549359       10.23958     12.309968      4.444329   1323.914069
# min        0.000000       63.00000     55.000000      0.000000    427.000000
# 25%     9792.250000       73.00000     69.000000      3.000000   1858.000000
# 50%    19584.500000       82.00000     79.000000      7.000000   2949.000000
# 75%    29376.750000       91.00000     89.000000     11.000000   4635.000000
# max    39169.000000       99.00000     99.000000     14.000000   4976.000000
#
#              budget
# count  3.917000e+04
# mean   2.117241e+06
# std    8.749987e+05
# min    2.480870e+05
# 25%    1.081356e+06
# 50%    1.910635e+06
# 75%    3.022020e+06
# max    3.124928e+06

# %%
# Total number of schools
total_num_school = school_data['school_name'].count()
total_num_school
# Out:
# 15

# %%
# Total number of students
total_num_stud = student_data['student_name'].count()
total_num_stud
# Out:
# 39170

# %%
# Total budget
total_budget = school_data_complete['budget'].sum()
total_budget
# Out:
# 82932329558

# %%
# Average math score
avg_math_score = school_data_complete['math_score'].mean()
avg_math_score
# Out:
# 78.98537145774827

# %%
# Average reading score
avg_reading_score = school_data_complete['reading_score'].mean()
avg_reading_score
# Out:
# 81.87784018381414

# %%
# Overall average score
avg_score = (school_data_complete['math_score'].mean() + 
             school_data_complete['reading_score'].mean())/2 
avg_score
# Out:
# 80.43160582078121

# %%
school_data_complete.set_index('student_name')
# Out:
#                    Student ID gender grade         school_name  reading_score  \
# student_name
# Paul Bradley                0      M   9th   Huang High School             66
# Victor Smith                1      M  12th   Huang High School             94
# Kevin Rodriguez             2      M  12th   Huang High School             90
# Dr. Richard Scott           3      M  12th   Huang High School             67
# Bonnie Ray                  4      F   9th   Huang High School             97
# ...                       ...    ...   ...                 ...            ...
# Donna Howard            39165      F  12th  Thomas High School             99
# Dawn Bell               39166      F  10th  Thomas High School             95
# Rebecca Tanner          39167      F   9th  Thomas High School             73
# Desiree Kidd            39168      F  10th  Thomas High School             99
# Carolyn Jackson         39169      F  11th  Thomas High School             95
#
# ...

# %%
# Percentage of passing math (70 or greater)
passing_math = school_data_complete.loc[(school_data_complete["math_score"] > 70)].math_score.count() / school_data_complete.shape[0]
passing_math

# school_data_complete.groupby('math_score').apply(lambda x: (x['math_score'] >= 70)).sum() / len(school_data_complete)

# percentage_passing_math = (school_data_complete['math_score'] >= 70)
# Out:
# 0.7239213683941792

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)
#
# * Create a dataframe to hold the above results

# %% [markdown]
# ### Top Performing Schools (By Passing Rate)

# %% [markdown]
# * Sort and display the top five schools in overall passing rate

# %%
#  Sort and display the top five schools in overall passing rate
# top_five = school_data_complete.groupby('avg_score').sort_values()
# top_five.head(5)

group_schools = school_data_complete.groupby(['school_name'])
average_grouped_reading_score = group_schools['reading_score'].mean().values
average_grouped_math_score = group_schools['math_score'].mean().values

math_passing = school_data_complete.loc[(school_data_complete["math_score"] > 70)]
read_passing = school_data_complete.loc[(school_data_complete["reading_score"] > 70)]

school_summary = school_data.sort_values("school_name")
school_size = school_summary["size"]
school_summary["math_pass"] = (math_passing.groupby(["school_name"]).count()["Student ID"].values / school_size)
school_summary["reading_pass"] = (read_passing.groupby(["school_name"]).count()["Student ID"].values / school_size)
school_summary["overall_passing_rate"] = ((school_summary["math_pass"]+school_summary["reading_pass"])/2).astype(float).map('{:,.2%}'.format)



# overall_passing_rate = 

top_five = school_summary.sort_values("overall_passing_rate",ascending=False)
top_five.head()
# top_five.head()
# Out:
#     School ID          school_name     type  size   budget  math_pass  \
# 5           5   Wilson High School  Charter  2283  1319574   0.909330
# 9           9     Pena High School  Charter   962   585858   0.916840
# 10         10   Wright High School  Charter  1800  1049400   0.902778
# 6           6  Cabrera High School  Charter  1858  1081356   0.895587
# 8           8   Holden High School  Charter   427   248087   0.906323
#
#     reading_pass overall_passing_rate
# 5       0.932545               92.09%
# 9       0.922037               91.94%
# 10      0.934444               91.86%
# 6       0.938644               91.71%
# 8       0.927400               91.69%

# %%
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# ...

# %%
# Calculate total school budget
school_data_complete.groupby('school_name').first()['budget'].sum()
# Out:
# 24649428

# %%
# Calculate per student budget
student_per_budget = (
    school_data_complete.groupby('school_name').first()['budget'] /
    school_data_complete.groupby('school_name').count()['student_name']
)

student_per_budget = pd.DataFrame(student_per_budget).reset_index()
student_per_budget
# Out:
#               school_name      0
# 0      Bailey High School  628.0
# 1     Cabrera High School  582.0
# 2    Figueroa High School  639.0
# 3        Ford High School  644.0
# 4     Griffin High School  625.0
# 5   Hernandez High School  652.0
# 6      Holden High School  581.0
# 7       Huang High School  655.0
# 8     Johnson High School  650.0
# 9        Pena High School  609.0
# 10  Rodriguez High School  637.0
# 11    Shelton High School  600.0
# 12     Thomas High School  638.0
# 13     Wilson High School  578.0
# 14     Wright High School  583.0

# %%
# Cacluate the avg math and reading score
(np.average(school_data_complete['math_score']), np.average(school_data_complete['reading_score']))
# Out:
# (78.98537145774827, 81.87784018381414)

# %% [markdown]
# #### Find the passing rate for math and reading (above 70 points)

# %%
school_data_complete[school_data_complete['math_score'] > 70]
# Out:
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# 5               5    Bryan Miranda      M   9th   Huang High School
# 6               6    Sheena Carter      F  11th   Huang High School
# 8               8     Michael Roth      M  10th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39164       39164   Joseph Anthony      M   9th  Thomas High School
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 0                 66          79          0  District  2917  1910635
# ...

# %%
school_data_complete['math_score']
# Out:
# 0        79
# 1        61
# 2        60
# 3        58
# 4        84
#          ..
# 39165    90
# 39166    70
# 39167    84
# 39168    90
# 39169    75
# Name: math_score, Length: 39170, dtype: int64

# %%
# Find the total counts of math result
school_data_complete.shape[0]

# Find the counts for math result in each school that pass 70 or higher
school_data_complete[school_data_complete['math_score'] > 70].shape[0]

# Calculate the math passing rate
(school_data_complete[school_data_complete['math_score'] > 70].shape[0] / school_data_complete.shape[0])
# Out:
# 0.7239213683941792

# %%
# Find the total counts of read result
school_data_complete.shape[0]

# Find the counts for read result in each school that pass 70 or higher
school_data_complete[school_data_complete['reading_score'] > 70].shape[0]

# Calculate the read passing rate
(school_data_complete[school_data_complete['reading_score'] > 70].shape[0] / school_data_complete.shape[0])
# Out:
# 0.8297166198621394

# %%
# Calculate the overall passing rate (average of the math and reading passing rate)
school_data_complete['total_score'] = (school_data_complete['math_score']+school_data_complete['reading_score'])/2
(school_data_complete[school_data_complete['total_score'] > 70].shape[0] / school_data_complete.shape[0])
# Out:
# 0.8823334184324738

# %% [markdown]
# ### Bottom Performing Schools (By Passing Rate)

# %% [markdown]
# * Sort and display the five worst-performing schools

# %%
#  Sort and display the worst five schools in overall passing rate
top_five = school_summary.sort_values("overall_passing_rate",ascending=True)
top_five.head()
# Out:
#     School ID            school_name      type  size   budget  math_pass  \
# 11         11  Rodriguez High School  District  3999  2547363   0.640660
# 0           0      Huang High School  District  2917  1910635   0.633185
# 12         12    Johnson High School  District  4761  3094650   0.638521
# 1           1   Figueroa High School  District  2949  1884411   0.637504
# 3           3  Hernandez High School  District  4635  3022020   0.647465
#
#     reading_pass overall_passing_rate
# 11      0.777444               70.91%
# 0       0.788138               71.07%
# 12      0.782819               71.07%
# 1       0.784334               71.09%
# 3       0.781877               71.47%

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
# Create table that lists the average math score for each school of each grade level.
dog = school_data_complete.groupby(['grade', 'school_name']).agg(np.mean)

dog
# Out:
#                                Student ID  reading_score  math_score  \
# grade school_name
# 10th  Bailey High School     20365.058918      80.907183   76.996772
#       Cabrera High School    16909.487124      84.253219   83.154506
#       Figueroa High School    4332.703801      81.408912   76.539974
#       Ford High School       36122.879944      81.262712   77.672316
#       Griffin High School    12983.711823      83.706897   84.229064
#       Hernandez High School   9930.783211      80.660147   77.337408
#       Holden High School     23076.342105      83.324561   83.429825
#       Huang High School       1450.796610      81.512386   75.908735
#       Johnson High School    32467.993480      80.773431   76.691117
#       Pena High School       23769.208000      83.612000   83.372000
#       Rodriguez High School  28050.171154      80.629808   76.612500
#       Shelton High School     6748.301339      83.441964   82.917411
# ...

# %%
# Calculate the average math score for 9th grade in each school
dog.loc['9th', 'math_score']
# Out:
# school_name
# Bailey High School       77.083676
# Cabrera High School      83.094697
# Figueroa High School     76.403037
# Ford High School         77.361345
# Griffin High School      82.044010
# Hernandez High School    77.438495
# Holden High School       83.787402
# Huang High School        77.027251
# Johnson High School      77.187857
# Pena High School         83.625455
# Rodriguez High School    76.859966
# Shelton High School      83.420755
# Thomas High School       83.590022
# Wilson High School       83.085578
# Wright High School       83.264706
# Name: math_score, dtype: float64

# %%
# Calculate the average math score for 10th grade in each school
dog.loc['10th', 'math_score']
# Out:
# school_name
# Bailey High School       76.996772
# Cabrera High School      83.154506
# Figueroa High School     76.539974
# Ford High School         77.672316
# Griffin High School      84.229064
# Hernandez High School    77.337408
# Holden High School       83.429825
# Huang High School        75.908735
# Johnson High School      76.691117
# Pena High School         83.372000
# Rodriguez High School    76.612500
# Shelton High School      82.917411
# Thomas High School       83.087886
# Wilson High School       83.724422
# Wright High School       84.010288
# Name: math_score, dtype: float64

# %%
# Calculate the average math score for 11th grade in each school
dog.loc['11th', 'math_score']
# Out:
# school_name
# Bailey High School       77.515588
# Cabrera High School      82.765560
# Figueroa High School     76.884344
# Ford High School         76.918058
# Griffin High School      83.842105
# Hernandez High School    77.136029
# Holden High School       85.000000
# Huang High School        76.446602
# Johnson High School      77.491653
# Pena High School         84.328125
# Rodriguez High School    76.395626
# Shelton High School      83.383495
# Thomas High School       83.498795
# Wilson High School       83.195326
# Wright High School       83.836782
# Name: math_score, dtype: float64

# %%
# Calculate the average math score for 12th grade in each school
dog.loc['12th', 'math_score']
# Out:
# school_name
# Bailey High School       76.492218
# Cabrera High School      83.277487
# Figueroa High School     77.151369
# Ford High School         76.179963
# Griffin High School      83.356164
# Hernandez High School    77.186567
# Holden High School       82.855422
# Huang High School        77.225641
# Johnson High School      76.863248
# Pena High School         84.121547
# Rodriguez High School    77.690748
# Shelton High School      83.778976
# Thomas High School       83.497041
# Wilson High School       83.035794
# Wright High School       83.644986
# Name: math_score, dtype: float64

# %% [markdown]
# ### Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
# Create table that lists the average reading score for each school of each grade level.
dog
# Out:
#                                Student ID  reading_score  math_score  \
# grade school_name
# 10th  Bailey High School     20365.058918      80.907183   76.996772
#       Cabrera High School    16909.487124      84.253219   83.154506
#       Figueroa High School    4332.703801      81.408912   76.539974
#       Ford High School       36122.879944      81.262712   77.672316
#       Griffin High School    12983.711823      83.706897   84.229064
#       Hernandez High School   9930.783211      80.660147   77.337408
#       Holden High School     23076.342105      83.324561   83.429825
#       Huang High School       1450.796610      81.512386   75.908735
#       Johnson High School    32467.993480      80.773431   76.691117
#       Pena High School       23769.208000      83.612000   83.372000
#       Rodriguez High School  28050.171154      80.629808   76.612500
#       Shelton High School     6748.301339      83.441964   82.917411
# ...

# %%
# Calculate the average reading score for 9th grade in each school
dog.loc['9th', 'reading_score']
# Out:
# school_name
# Bailey High School       81.303155
# Cabrera High School      83.676136
# Figueroa High School     81.198598
# Ford High School         80.632653
# Griffin High School      83.369193
# Hernandez High School    80.866860
# Holden High School       83.677165
# Huang High School        81.290284
# Johnson High School      81.260714
# Pena High School         83.807273
# Rodriguez High School    80.993127
# Shelton High School      84.122642
# Thomas High School       83.728850
# Wilson High School       83.939778
# Wright High School       83.833333
# Name: reading_score, dtype: float64

# %%
# Calculate the average reading score for 10th grade in each school
dog.loc['10th', 'reading_score']
# Out:
# school_name
# Bailey High School       80.907183
# Cabrera High School      84.253219
# Figueroa High School     81.408912
# Ford High School         81.262712
# Griffin High School      83.706897
# Hernandez High School    80.660147
# Holden High School       83.324561
# Huang High School        81.512386
# Johnson High School      80.773431
# Pena High School         83.612000
# Rodriguez High School    80.629808
# Shelton High School      83.441964
# Thomas High School       84.254157
# Wilson High School       84.021452
# Wright High School       83.812757
# Name: reading_score, dtype: float64

# %%
# Calculate the average reading score for 11th grade in each school
dog.loc['11th', 'reading_score']
# Out:
# school_name
# Bailey High School       80.945643
# Cabrera High School      83.788382
# Figueroa High School     80.640339
# Ford High School         80.403642
# Griffin High School      84.288089
# Hernandez High School    81.396140
# Holden High School       83.815534
# Huang High School        81.417476
# Johnson High School      80.616027
# Pena High School         84.335938
# Rodriguez High School    80.864811
# Shelton High School      84.373786
# Thomas High School       83.585542
# Wilson High School       83.764608
# Wright High School       84.156322
# Name: reading_score, dtype: float64

# %%
# Calculate the average reading score for 12th grade in each school
dog.loc['12th', 'reading_score']
# Out:
# school_name
# Bailey High School       80.912451
# Cabrera High School      84.287958
# Figueroa High School     81.384863
# Ford High School         80.662338
# Griffin High School      84.013699
# Hernandez High School    80.857143
# Holden High School       84.698795
# Huang High School        80.305983
# Johnson High School      81.227564
# Pena High School         84.591160
# Rodriguez High School    80.376426
# Shelton High School      82.781671
# Thomas High School       83.831361
# Wilson High School       84.317673
# Wright High School       84.073171
# Name: reading_score, dtype: float64

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
# Sample bins. Feel free to create your own bins.
spending_bins = [0, 585, 615, 645, 675]
group_names = ["<$585", "$585-615", "$615-645", "$645-675"]

# %%
# Create a new column to show budget per student in each row
# school_data_complete["budget_per_student"]=school_data_complete.join()

school_data_complete2 = school_data_complete.merge(student_per_budget, on='school_name', how='inner').rename(columns={0: 'budget_per_student'})
school_data_complete2
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget  \
# ...

# %%
# Create a new column to define the spending ranges per student
def budget_to_bin(budget):
    if (budget >= spending_bins[0]) & (budget < spending_bins[1]):
        return group_names[0]
    elif (budget >= spending_bins[1]) & (budget < spending_bins[2]):
        return group_names[1]
    elif (budget >= spending_bins[2]) & (budget < spending_bins[3]):
        return group_names[2]
    else:
        return group_names[3]


school_data_complete2['budget_bins'] = school_data_complete2['budget_per_student'].apply(budget_to_bin)
school_data_complete2
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget  \
# ...

# %%
# Calculate the average math score within each spending range
school_data_complete2.groupby('budget_bins').mean()
# Out:
#                Student ID  reading_score  math_score  School ID         size  \
# budget_bins
# $585-615     12754.878810      83.838414   83.529196   4.473008  1478.723834
# $615-645     22920.396769      81.434088   78.061635   8.225768  3477.403355
# $645-675     16622.369934      81.005604   77.049297   5.769268  4276.718509
# <$585        18925.615578      83.964039   83.363065   6.906250  1898.018530
#
#                    budget  total_score  budget_per_student
# budget_bins
# $585-615     8.902931e+05    83.683805          603.179581
# $615-645     2.205192e+06    79.747861          634.990881
# $645-675     2.786812e+06    79.027451          651.937383
# <$585        1.101853e+06    83.663552          580.781564

# %%
# Calculate the percentage passing rate for math in each spending range
#school_data_complete2.groupby('budget_bins').

def pass_nopass(score):
    return np.mean(score >= 70)

school_data_complete2[['math_score', 'budget_bins']].groupby('budget_bins').agg(pass_nopass).rename(columns={'math_score': 'math passing rate'})
# Out:
#              math passing rate
# budget_bins
# $585-615              0.941241
# $615-645              0.714004
# $645-675              0.662308
# <$585                 0.937029

# %%
# Calculate the percentage passing rate for reading in each spending range

def pass_nopass(score):
    return np.mean(score >= 70)

school_data_complete2[['reading_score', 'budget_bins']].groupby('budget_bins').agg(pass_nopass).rename(columns={'reading_score': 'reading passing rate'})
# Out:
#              reading passing rate
# budget_bins
# $585-615                 0.958869
# $615-645                 0.836148
# $645-675                 0.811094
# <$585                    0.966866

# %%
# Calculate the percentage overall passing rate in each spending range
school_data_complete2[['total_score', 'budget_bins']].groupby('budget_bins').agg(pass_nopass).rename(columns={'total_score': 'total passing rate'})
# Out:
#              total passing rate
# budget_bins
# $585-615               0.993022
# $615-645               0.873973
# $645-675               0.849427
# <$585                  0.992933

# %% [markdown]
# ### Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# Sample bins. Feel free to create your own bins.
size_bins = [0, 1000, 2000, 5000]
group_names = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

# %%
# Create a new column for the bin groups
def size_to_bin(size):
    if (size >= size_bins[0]) & (size < size_bins[1]):
        return group_names[0]
    elif (size >= size_bins[1]) & (size < size_bins[2]):
        return group_names[1]
    elif (size >= size_bins[2]) & (size < size_bins[3]):
        return group_names[2]
    else:
        return group_names[3]

school_data_complete2['size_bins'] = school_data_complete2['size'].apply(size_to_bin)

#school_data_complete2['budget_bins'] = school_data_complete2['budget_per_student'].apply(budget_to_bin)
school_data_complete2
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget  \
# ...

# %% [markdown]
# Look for the total count of test scores that pass 70% or higher

# %%
# math_pass_size

def pass_nopass(score):
    return sum(score >= 70)

school_data_complete2[['math_score', 'size_bins']].groupby('size_bins').agg(pass_nopass).rename(columns={'math_score': 'math passing size'})
# Out:
#                     math passing size
# size_bins
# Large (2000-5000)               20087
# Medium (1000-2000)               7978
# Small (<1000)                    1305

# %%
# read_pass_size

def pass_nopass(score):
    return sum(score >= 70)

school_data_complete2[['reading_score', 'size_bins']].groupby('size_bins').agg(pass_nopass).rename(columns={'reading_score': 'reading passing size'})
# Out:
#                     reading passing size
# size_bins
# Large (2000-5000)                  24029
# Medium (1000-2000)                  8247
# Small (<1000)                       1334

# %%
# Calculate the overall passing rate for different school size

def pass_nopass(score):
    return sum(score >= 70)

school_data_complete2[['total_score', 'size_bins']].groupby('size_bins').agg(pass_nopass).rename(columns={'total_score': 'total passing size'})
# Out:
#                     total passing size
# size_bins
# Large (2000-5000)                25172
# Medium (1000-2000)                8466
# Small (<1000)                     1375

# %% [markdown]
# ### Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type.

# %%
# Create bins and groups, school type {'Charter', 'District'}

size_bins = [0, 1000, 2000, 5000]

# %% [markdown]
# Find counts of the passing 70 or higher score for the both test

# %%
# math pass size

def pass_nopass(score):
    return sum(score >= 70)

school_data_complete2[['math_score', 'type']].groupby('type').agg(pass_nopass).rename(columns={'math_score': 'math passing size'})
# Out:
#           math passing size
# type
# Charter               11426
# District              17944

# %%
# reading pass size

def pass_nopass(score):
    return sum(score >= 70)

school_data_complete2[['reading_score', 'type']].groupby('type').agg(pass_nopass).rename(columns={'reading_score': 'reading passing size'})
# Out:
#           reading passing size
# type
# Charter                  11785
# District                 21825

# %%
# Calculate the overall passing rate

def pass_nopass(score):
    return sum(score >= 70)

school_data_complete2[['total_score', 'type']].groupby('type').agg(pass_nopass).rename(columns={'total_score': 'total passing size'})
# Out:
#           total passing size
# type
# Charter                12107
# District               22906
